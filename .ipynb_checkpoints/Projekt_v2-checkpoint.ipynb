# %% [markdown]
# # BDINF project SS2024

# %% [markdown]
# ## Topic
#
# The main goal is to check if there is a correlation between CO2 emissions and between new/used registered cars in AT (since 200). It would be also good to know how the CO2 emission did reduce over time for newly registered cars as a percentage.

# %% [markdown]
# Members: Grégoire Bartek, Matthias Huber, David Berger

# %% [markdown]
# ## Data Sources:

# %% [markdown]
# Planned Data Source: It is planned to store the data in a MYSQL database. The data from newly registered cars and used regeistered cars will be stored in a seperate tables and the emission data will be stored in a third table, we are currently in the process finding good APIs.

# %% [markdown]
# AT new registered cars: https://www.data.gv.at/katalog/de/dataset/stat_pkw-neuzulassungen-nach-marken-ab-janner-2000#resources

# %% [markdown]
# AT used registered cars: https://www.data.gv.at/katalog/dataset/6fc1c927-bf21-3d72-9333-a9055493ab3c#additional-info

# %% [markdown]
# emission data: https://www.data.gv.at/katalog/dataset/bd462a04-2453-4c76-95bb-cfbd043540f5#resources (trendbericht nach sektoren)

# %% [markdown]
# # Load the data from the CSV file

# %% [markdown]
# ## Planned procedure :

# %% [markdown]
# MYSQL DB is running in a docker container, which will be versioned in the following Github repository (This is accomplished because we want to save Azure credits):

# %% [markdown]
# https://github.com/huhubi/BDINF_project

# %% [markdown]
# The queries will be made from this notebook, so the outcome is reproducable

# %% [markdown]
# ## Expected Output :

# %% [markdown]
# The data will be visualized and described in this notebook, it is expected to find a correlation between lower emissions and the production year of cars

# %% [markdown]
# # Documentation of procedure

# %% [markdown]
# First, we are downloading the csv data and doing explorative data analysis from AT emissions to check which categories are fitting for the car data. Since the data is from the years 1990-2022, and the car data is from 2000, just the emissions from 2000 are being considered. We also transformed the csv file to a xlsx file so we dont get any encoding issue

# %% [markdown]
# First, we get the CO2 data from the emissions csv. Here we are looking at the line 33, which has the yearly CO2 data from transport. Now we write us a script which gets just the line we want (in our case line 33, for transport)

# %%
import pandas as pd

# Load the CSV file with a specified delimiter
data = pd.read_csv('emissions/schadstoffemissionen_1990-2022_nach_nfr_wide_1a3b1.csv', delimiter=';')

# Apply the filter for 'NFR_Code' equals '1 A 3 b 1' and 'Schadstoff' equals 'CO'
filtered_data = data[(data['NFR_Code'] == '1 A 3 b 1') & (data['Schadstoff'] == 'CO')]

# Print the number of rows to see how many entries we have
print("Number of entries matching '1 A 3 b 1' and 'CO':", filtered_data.shape[0])

# Proceed if there are any rows after filtering
if filtered_data.shape[0] > 0:
    # Access the first row, or any specific row, as needed
    year_data = filtered_data.iloc[0]  # Adjust .iloc[0] to another index if needed

    # Create a DataFrame with just this row of year data
    cleaned_data = pd.DataFrame([year_data])

    # Write the DataFrame to a new Excel file
    cleaned_data.to_excel('emissions/cleaned_co_emissions_1a3b1.xlsx', index=False)

    print("Excel file has been created with the required data.")
else:
    print("No data matches the specified filters.")
# Out:
# Number of entries matching '1 A 3 b 1' and 'CO': 1
# Excel file has been created with the required data.

# %% [markdown]
# we need a little bit more cleanup

# %%
import pandas as pd

def clean_excel_data(input_path, output_path):
    # Load the original Excel file
    data = pd.read_excel(input_path)
    
    # Keep only columns with year data, starting from 1990 to the latest available year
    year_columns = [col for col in data.columns if col.isdigit() and int(col) >= 1990]
    cleaned_data = data[year_columns]
    
    # Convert data types to float, ensuring that commas are treated as decimal separators
    cleaned_data = cleaned_data.apply(lambda x: x.str.replace(',', '.').astype(float))
    
    # Save the cleaned data to a new Excel file
    cleaned_data.to_excel(output_path, index=False)


# Paths to the files (update these paths as necessary)
input_file_path = 'emissions/cleaned_co_emissions_1a3b1.xlsx'
output_file_path = 'emissions/cleaned_co_emissions.xlsx'

# Call the function to clean the data
clean_excel_data(input_file_path, output_file_path)

# %% [markdown]
# now we can vizualize the data

# %% [markdown]
# the excel data has to be the same format as the csv data so we can make the vizualization, in order for that we need one more step

# %%
import pandas as pd

# Load the Excel file
excel_path = 'emissions/1a3b1.xlsx'
excel_data = pd.read_excel(excel_path)

# Transpose the data to get years as the index
excel_data_transposed = excel_data.transpose()

# Reset the index to make 'Year' a column instead of the index
excel_data_transposed.reset_index(inplace=True)

# Rename the columns to match the format 'Year' and 'CO2 Emissions'
excel_data_transposed.columns = ['Year', 'CO2 Emissions']

# Now you have the DataFrame 'excel_data_transposed' in the desired format
# Display the first few rows to confirm the transformation
print(excel_data_transposed.head())

# If you need to save this to a CSV file, uncomment the following line:
excel_data_transposed.to_csv('emissions/1a3b1.csv', index=False)
# Out:
#    Year  CO2 Emissions
# 0  1990     464.972529
# 1  1991     470.133014
# 2  1992     409.771877
# 3  1993     355.593462
# 4  1994     311.225494

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the cleaned data
cleaned_data_path = 'your_path_here/1a3b1.csv'  # Replace 'your_path_here' with the correct path to the cleaned data
cleaned_data = pd.read_csv(cleaned_data_path)

# Ensure the column names are strings if they appear to be in a different format
cleaned_data.columns = cleaned_data.columns.map(str)

# Filter the data for the years 2000 to 2022
years = [str(year) for year in range(2000, 2023)]
austria_co2 = cleaned_data[years].transpose()

# Rename the index and columns for clarity
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(austria_co2.index, austria_co2['CO2 Emissions'], marker='o', linestyle='-', color='blue')
plt.title('CO2 Transit Emissions in Austria from 2000 to 2022')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (tons)')
plt.grid(True)
plt.tight_layout()

# Save the plot as a PNG file
graph_path = 'your_path_here/austria_co2_emissions_2000_2022.png'  # Replace 'your_path_here' with your desired file path
plt.savefig(graph_path, format='png', dpi=300)  # Save in high resolution

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 13
#      11 # Filter the data for the years 2000 to 2022
#      12 years = [str(year) for year in range(2000, 2023)]  # Use string years if the column names are strings
# ---> 13 austria_co2 = cleaned_data[years].transpose()
#      15 # Rename the index and columns for clarity
#      16 austria_co2.index.name = 'Year'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
# ...

# %% [markdown]
# # New vehicles

# %% [markdown]
# C-J59-0 --> Passenger car names
#
# C-A10-0 --> Time (monthly values)
#
# C-EK7-0 --> vehicle type
#
# F-ISIS-1 --> count

# %% [markdown]
# # Used vehicles

# %% [markdown]
# C-J59-0 --> Passenger car names
#
# C-A10-0 --> Time (monthly values)
#
# C-EK7-0 --> vehicle type
#
# F-ISIS-1 --> count

# %% [markdown]
# ### New cars count per year

# %%
# Load the CSV to check the structure
file_path = 'newcars/overalldata.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe and the column names to understand its structure
data.head(), data.columns

# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert the data types: F-ISIS-1 to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'])

# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert the data types: F-ISIS-1 to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'])

# Display the first few rows of the new dataframe
data_split.head()

filtered_yearly_sum = yearly_sum[(yearly_sum['Year'] >= 2000) & (yearly_sum['Year'] <= 2022)]

# Show the result of the filtered data
filtered_yearly_sum
# Out:
#     Year  F-ISIS-1
# 0   2000    750630
# 1   2001    756630
# 2   2002    747319
# 3   2003    751276
# 4   2004    776794
# 5   2005    771242
# 6   2006    774192
# 7   2007    745566
# 8   2008    738690
# 9   2009    773809
# 10  2010    798652
# 11  2011    802458
# 12  2012    808384
# 13  2013    823417
# 14  2014    810994
# 15  2015    816116
# 16  2016    841310
# 17  2017    853244
# 18  2018    874827
# 19  2019    872043
# 20  2020    841196
# 21  2021    871065
# 22  2022    751011

# %%
file_path = 'emissions/1a3b1.csv'
data = pd.read_csv(file_path)
data.head(), data.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[79], line 2
#       1 file_path = 'emissions/1a3b1.csv'
# ----> 2 data = pd.read_csv(file_path)
#       3 data.head(), data.columns
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Plot the filtered data
plt.figure(figsize=(12, 6))
plt.plot(filtered_yearly_sum['Year'], filtered_yearly_sum['F-ISIS-1'], marker='o')
plt.title('Sum of new cars by year from 2000 to 2022')
plt.xlabel('Year')
plt.ylabel('Sum of new cars')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# now we summarized the count of new cars with the emissions, lets repeat the process for used cars and sum up the count!

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'austria_co2' and 'filtered_yearly_sum' DataFrames are already loaded and preprocessed.

# Plot settings
fig, ax1 = plt.subplots(figsize=(14, 7))
plt.title('CO2 Emissions and Number of New Cars from 2000 to 2022 in Austria')

# Plotting the car data on the primary y-axis
ax1.set_xlabel('Year')
ax1.set_ylabel('Total New Cars', color='red')
line1 = ax1.plot(filtered_yearly_sum['Year'], filtered_yearly_sum['F-ISIS-1'], marker='s', linestyle='--', color='red', label='Total New Cars')
ax1.tick_params(axis='y', labelcolor='red')

# Adjust the x-axis to have a clear view of the years
ax1.set_xticks(filtered_yearly_sum['Year'])  # This ensures every year has a tick
ax1.set_xticklabels(filtered_yearly_sum['Year'], rotation=45)  # Rotate the labels for better legibility

# Creating a secondary y-axis for the CO2 emissions data
ax2 = ax1.twinx()
ax2.set_ylabel('CO2 Emissions (kt)', color='blue')
line2 = ax2.plot(austria_co2.index, austria_co2['CO2-Emissionen'] / 1000, marker='o', linestyle='-', color='blue', label='CO2 Emissions (kt)')  # Converting tonnes to kilotonnes
ax2.tick_params(axis='y', labelcolor='blue')

# Adding legends
lns = line1 + line2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='upper left')

# Tight layout for proper spacing
plt.tight_layout()

# Save the plot as a PNG file
plt.savefig('austria_combined_emissions_and_cars_2000_2022.png')

# Show the plot
plt.show()

# %% [markdown]
# ### Open TODOs
#
# - [x] create sum of new cars
# - [ ] adapt y axis of graph
# - [ ] create mysql/nosql docker container
# - [ ] import emission/car data to database
# - [x] create sum of used cars

# %% [markdown]
# # New car data

# %%
import pandas as pd

# load in data

file_path_used = 'usedcars/overalldata_used.csv'
data_used = pd.read_csv(file_path)

# Display the first few rows of the dataframe and the column names to understand its structure
data_used.head(), data_used.columns
# Out:
# (  C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1
#  0       J59-225;A10-200805;EK7-1;5
#  1       J59-225;A10-200806;EK7-1;4
#  2      J59-225;A10-200807;EK7-1;20
#  3      J59-225;A10-200808;EK7-1;15
#  4      J59-225;A10-200809;EK7-1;11,
#  Index(['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'], dtype='object'))

# %%
# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert the data types: F-ISIS-1 to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'])

# Display the first few rows of the new dataframe
data_split.head()
# Out:
#   C-J59-0     C-A10-0 C-EK7-0  F-ISIS-1
# 0   J59-1  A10-200001   EK7-1         1
# 1   J59-1  A10-200004   EK7-1         1
# 2   J59-1  A10-200005   EK7-1         1
# 3   J59-1  A10-200103   EK7-1         1
# 4   J59-1  A10-200105   EK7-1         1

# %%
# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert the data types: F-ISIS-1 to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'])

# Display the first few rows of the new dataframe
data_split.head()

filtered_yearly_sum_used = yearly_sum[(yearly_sum['Year'] >= 2000) & (yearly_sum['Year'] <= 2022)]

# Show the result of the filtered data
filtered_yearly_sum_used
# Out:
#     Year  F-ISIS-1
# 0   2000    750630
# 1   2001    756630
# 2   2002    747319
# 3   2003    751276
# 4   2004    776794
# 5   2005    771242
# 6   2006    774192
# 7   2007    745566
# 8   2008    738690
# 9   2009    773809
# 10  2010    798652
# 11  2011    802458
# 12  2012    808384
# 13  2013    823417
# 14  2014    810994
# 15  2015    816116
# 16  2016    841310
# 17  2017    853244
# 18  2018    874827
# 19  2019    872043
# 20  2020    841196
# 21  2021    871065
# 22  2022    751011

# %% [markdown]
# # Used car data and correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = 'usedcars/overalldata_used.csv'
data = pd.read_csv(file_path)

# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert 'F-ISIS-1' to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'], errors='coerce')

# Extract year from 'C-A10-0'
data_split['Year'] = data_split['C-A10-0'].str.slice(4, 8).astype(int)

# Filter the DataFrame to include only the years from 2000 to 2022
filtered_data = data_split[(data_split['Year'] >= 2000) & (data_split['Year'] <= 2022)]

# Group by 'Year' and sum up 'F-ISIS-1'
yearly_sum = filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Display the result
print(yearly_sum)


# Assuming 'yearly_sum' has already been created with the above code block you provided
# Load the emissions data
cleaned_data_path = 'emissions/cleaned_co_emissions.xlsx'  # Replace with the correct path to the cleaned data
cleaned_data = pd.read_excel(cleaned_data_path)

# Filter the data for the years 2000 to 2022
years = list(range(2000, 2023))  # These are the column names in the emissions data
austria_co2 = cleaned_data[years].transpose()

# Rename the index and columns for clarity in the emissions data
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Ensure 'Year' in both datasets is the same dtype, ideally int for proper alignment
yearly_sum['Year'] = yearly_sum['Year'].astype(int)

# Merge the two datasets on the 'Year' column
combined_data = austria_co2.join(yearly_sum.set_index('Year'), how='inner')

# Plot the data
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(combined_data.index, combined_data['CO2 Emissions'], marker='o', label='CO2 Emissions (tons)')
plt.title('CO2 Emissions in Austria (2000-2022)')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (tons)')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_data.index, combined_data['F-ISIS-1'], marker='o', color='red', label='Used Car Data Metric')
plt.title('Used Car Data Metric (2000-2022)')
plt.xlabel('Year')
plt.ylabel('Metric Value')
plt.grid(True)
plt.legend()

plt.tight_layout()

# Save the plot as a PNG file
graph_path = 'emissions/austria_co2_emissions_2000_2022.png'  # Replace with your desired file path
plt.savefig(graph_path)

plt.show()
# Out:
#     Year  F-ISIS-1
# 0   2000    750630
# 1   2001    756630
# 2   2002    747319
# 3   2003    751276
# 4   2004    776794
# 5   2005    771242
# 6   2006    774192
# 7   2007    745566
# 8   2008    738690
# 9   2009    773809
# 10  2010    798652
# 11  2011    802458
# 12  2012    808384
# 13  2013    823417
# 14  2014    810994
# 15  2015    816116
# 16  2016    841310
# 17  2017    853244
# 18  2018    874827
# 19  2019    872043
# 20  2020    841196
# 21  2021    871065
# 22  2022    751011
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 37
#      35 # Filter the data for the years 2000 to 2022
#      36 years = list(range(2000, 2023))  # These are the column names in the emissions data
# ---> 37 austria_co2 = cleaned_data[years].transpose()
#      39 # Rename the index and columns for clarity in the emissions data
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare the used car data
file_path = 'usedcars/overalldata_used.csv'
data = pd.read_csv(file_path)
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'], errors='coerce')
data_split['Year'] = data_split['C-A10-0'].str.slice(4, 8).astype(int)
filtered_data = data_split[(data_split['Year'] >= 2000) & (data_split['Year'] <= 2022)]
yearly_sum = filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Load and prepare the CO2 emissions data
cleaned_data_path = 'emissions/cleaned_co_emissions.xlsx'
cleaned_data = pd.read_excel(cleaned_data_path)
years = list(range(2000, 2023))
austria_co2 = cleaned_data[years].transpose()
austria_co2.index = austria_co2.index.astype(int)  # Convert index to integer for alignment
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Merge the two datasets on the 'Year' column
combined_data = yearly_sum.merge(austria_co2, on='Year', how='inner')

# Calculate and display the Pearson correlation coefficient
correlation = combined_data[['F-ISIS-1', 'CO2 Emissions']].corr()
print("Correlation Matrix:\n", correlation)

# Plot the combined data to visualize relationships
plt.figure(figsize=(10, 5))
plt.scatter(combined_data['CO2 Emissions'], combined_data['F-ISIS-1'])
plt.title('Scatter Plot of Used Car Data Metric vs. CO2 Emissions')
plt.xlabel('CO2 Emissions (tons)')
plt.ylabel('Used Car Data Metric (Sum of F-ISIS-1)')
plt.grid(True)
plt.show()

# Save the combined data table for reference
combined_data.to_csv('combined_data_correlation.csv', index=False)

# %% [markdown]
#     A coefficient close to 1 indicates a strong positive correlation, meaning as one variable increases, the other also increases.
#     A coefficient close to -1 indicates a strong negative correlation, meaning as one variable increases, the other decreases.
#     A coefficient close to 0 suggests no linear correlation between the variables.

# %% [markdown]
# # New car data and correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = 'newcars/overalldata.csv'
data = pd.read_csv(file_path)

# Split the single column into separate columns by the semicolon delimiter
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)

# Rename the columns based on the assumed headers from the original column names
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']

# Convert 'F-ISIS-1' to numeric for summation
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'], errors='coerce')

# Extract year from 'C-A10-0'
data_split['Year'] = data_split['C-A10-0'].str.slice(4, 8).astype(int)

# Filter the DataFrame to include only the years from 2000 to 2022
filtered_data = data_split[(data_split['Year'] >= 2000) & (data_split['Year'] <= 2022)]

# Group by 'Year' and sum up 'F-ISIS-1'
yearly_sum = filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Display the result
print(yearly_sum)



# Assuming 'yearly_sum' has already been created with the above code block you provided
# Load the emissions data
cleaned_data_path = 'emissions/cleaned_co_emissions.xlsx'  # Replace with the correct path to the cleaned data
cleaned_data = pd.read_excel(cleaned_data_path)

# Filter the data for the years 2000 to 2022
years = list(range(2000, 2023))  # These are the column names in the emissions data
austria_co2 = cleaned_data[years].transpose()

# Rename the index and columns for clarity in the emissions data
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Ensure 'Year' in both datasets is the same dtype, ideally int for proper alignment
yearly_sum['Year'] = yearly_sum['Year'].astype(int)

# Merge the two datasets on the 'Year' column
combined_data = austria_co2.join(yearly_sum.set_index('Year'), how='inner')

# Plot the data
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(combined_data.index, combined_data['CO2 Emissions'], marker='o', label='CO2 Emissions (tons)')
plt.title('CO2 Emissions in Austria (2000-2022)')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (tons)')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(combined_data.index, combined_data['F-ISIS-1'], marker='o', color='red', label='Used Car Data Metric')
plt.title('New Car Data Metric (2000-2022)')
plt.xlabel('Year')
plt.ylabel('Metric Value')
plt.grid(True)
plt.legend()

plt.tight_layout()

# Save the plot as a PNG file
graph_path = 'emissions/austria_co2_emissions_2000_2022.png'  # Replace with your desired file path
plt.savefig(graph_path)

plt.show()
# Out:
#     Year  F-ISIS-1
# 0   2000    309427
# 1   2001    293528
# 2   2002    279493
# 3   2003    300121
# 4   2004    311292
# 5   2005    307915
# 6   2006    308594
# 7   2007    298182
# 8   2008    293697
# 9   2009    319403
# 10  2010    328563
# 11  2011    356145
# 12  2012    336010
# 13  2013    319035
# 14  2014    303318
# 15  2015    308555
# 16  2016    329604
# 17  2017    353320
# 18  2018    341068
# 19  2019    329363
# 20  2020    248740
# 21  2021    239803
# 22  2022    215050
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 38
#      36 # Filter the data for the years 2000 to 2022
#      37 years = list(range(2000, 2023))  # These are the column names in the emissions data
# ---> 38 austria_co2 = cleaned_data[years].transpose()
#      40 # Rename the index and columns for clarity in the emissions data
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare the new car data
file_path = 'newcars/overalldata.csv'
data = pd.read_csv(file_path)
data_split = data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)
data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']
data_split['F-ISIS-1'] = pd.to_numeric(data_split['F-ISIS-1'], errors='coerce')
data_split['Year'] = data_split['C-A10-0'].str.slice(4, 8).astype(int)
filtered_data = data_split[(data_split['Year'] >= 2000) & (data_split['Year'] <= 2022)]
yearly_sum = filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Load and prepare the CO2 emissions data
cleaned_data_path = 'emissions/cleaned_co_emissions.xlsx'
cleaned_data = pd.read_excel(cleaned_data_path)
years = list(range(2000, 2023))
austria_co2 = cleaned_data[years].transpose()
austria_co2.index = austria_co2.index.astype(int)  # Convert index to integer for alignment
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Merge the two datasets on the 'Year' column
combined_data = yearly_sum.merge(austria_co2, on='Year', how='inner')

# Calculate and display the Pearson correlation coefficient
correlation = combined_data[['F-ISIS-1', 'CO2 Emissions']].corr()
print("Correlation Matrix:\n", correlation)

# Plot the combined data to visualize relationships
plt.figure(figsize=(10, 5))
plt.scatter(combined_data['CO2 Emissions'], combined_data['F-ISIS-1'])
plt.title('Scatter Plot of New Car Data Metric vs. CO2 Emissions')
plt.xlabel('CO2 Emissions (tons)')
plt.ylabel('New Car Data Metric (Sum of F-ISIS-1)')
plt.grid(True)
plt.show()

# Save the combined data table for reference
combined_data.to_csv('combined_data_correlation.csv', index=False)
# Out:
# Correlation Matrix:
#                 F-ISIS-1  CO2 Emissions
# F-ISIS-1       1.000000       0.208546
# CO2 Emissions  0.208546       1.000000

# %% [markdown]
# A coefficient close to 1 indicates a strong positive correlation, meaning as one variable increases, the other also increases.
#     A coefficient close to -1 indicates a strong negative correlation, meaning as one variable increases, the other decreases.
#     A coefficient close to 0 suggests no linear correlation between the variables.

# %% [markdown]
# ## Fragestellung: Ändert sich die Korrelation, wenn man beide Werte von gebraucht und Neuwagen aufsummiert?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare the new car data
new_car_path = 'newcars/overalldata.csv'
new_data = pd.read_csv(new_car_path)
new_data_split = new_data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)
new_data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']
new_data_split['F-ISIS-1'] = pd.to_numeric(new_data_split['F-ISIS-1'], errors='coerce')
new_data_split['Year'] = new_data_split['C-A10-0'].str.slice(4, 8).astype(int)
new_filtered_data = new_data_split[(new_data_split['Year'] >= 2000) & (new_data_split['Year'] <= 2022)]
new_yearly_sum = new_filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Load and prepare the used car data
used_car_path = 'usedcars/overalldata_used.csv'
used_data = pd.read_csv(used_car_path)
used_data_split = used_data['C-J59-0;C-A10-0;C-EK7-0;F-ISIS-1'].str.split(';', expand=True)
used_data_split.columns = ['C-J59-0', 'C-A10-0', 'C-EK7-0', 'F-ISIS-1']
used_data_split['F-ISIS-1'] = pd.to_numeric(used_data_split['F-ISIS-1'], errors='coerce')
used_data_split['Year'] = used_data_split['C-A10-0'].str.slice(4, 8).astype(int)
used_filtered_data = used_data_split[(used_data_split['Year'] >= 2000) & (used_data_split['Year'] <= 2022)]
used_yearly_sum = used_filtered_data.groupby('Year')['F-ISIS-1'].sum().reset_index()

# Combine new and used car data
combined_yearly_sum = pd.merge(new_yearly_sum, used_yearly_sum, on='Year', suffixes=('_new', '_used'))
combined_yearly_sum['Total F-ISIS-1'] = combined_yearly_sum['F-ISIS-1_new'] + combined_yearly_sum['F-ISIS-1_used']

# Load and prepare the CO2 emissions data
cleaned_data_path = 'emissions/cleaned_co_emissions.xlsx'
cleaned_data = pd.read_excel(cleaned_data_path)
years = list(range(2000, 2023))
austria_co2 = cleaned_data[years].transpose()
austria_co2.index = austria_co2.index.astype(int)  # Convert index to integer for alignment
austria_co2.index.name = 'Year'
austria_co2.columns = ['CO2 Emissions']

# Merge the combined car data with CO2 emissions data
final_combined_data = combined_yearly_sum.merge(austria_co2, on='Year', how='inner')

# Calculate and display the Pearson correlation coefficient
correlation = final_combined_data[['Total F-ISIS-1', 'CO2 Emissions']].corr()
print("Correlation Matrix:\n", correlation)

# Plot the combined data to visualize relationships
plt.figure(figsize=(10, 5))
plt.scatter(final_combined_data['CO2 Emissions'], final_combined_data['Total F-ISIS-1'])
plt.title('Scatter Plot of Total Car Data Metric vs. CO2 Emissions')
plt.xlabel('CO2 Emissions (tons)')
plt.ylabel('Total Car Data Metric (Sum of F-ISIS-1)')
plt.grid(True)
plt.show()

# Save the combined data table for reference
final_combined_data.to_csv('final_combined_data_correlation.csv', index=False)
# Out:
# Correlation Matrix:
#                  Total F-ISIS-1  CO2 Emissions
# Total F-ISIS-1        1.000000      -0.240301
# CO2 Emissions        -0.240301       1.000000

# %% [markdown]
# since the value is negative, there is a somewhat negative correlation --> the car values and emission data do not correlate

# %% [markdown]
# ### Get new emission data which reflects passenger cars

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
data = pd.read_excel('emissions/cleaned_co_emissions_1a3b1.xlsx')

# Focus on the years 2000-2022, assuming column names are like '2000', '2001', ..., '2022'
years = [str(year) for year in range(2000, 2023)]
kt_values = data[years].values.flatten()  # Extract data for the specified years

# Create a plot
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(years, kt_values, marker='o')
plt.title('CO Emissions from 2000 to 2022 (1 A 3 b 1)')
plt.xlabel('Year')
plt.ylabel('Emissions (kt)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
